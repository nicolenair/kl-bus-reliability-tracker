# %%
from google.transit import gtfs_realtime_pb2
from google.protobuf.json_format import MessageToDict
import pandas as pd
from requests import get
 
# Sample GTFS-R URL from Malaysia's Open API
URL = 'https://api.data.gov.my/gtfs-realtime/vehicle-position/prasarana?category=rapid-bus-kl'
 
# Parse the GTFS Realtime feed
feed = gtfs_realtime_pb2.FeedMessage()
response = get(URL)
feed.ParseFromString(response.content)
 
# Extract and print vehicle position information
vehicle_positions = [MessageToDict(entity.vehicle) for entity in feed.entity]
print(f'Total vehicles: {len(vehicle_positions)}')
df = pd.json_normalize(vehicle_positions)
# Out:
# Total vehicles: 1

# %%
vehicle_positions
# Out:
# [{'trip': {'tripId': '241209021024S2', 'routeId': 'T105'},
#   'position': {'latitude': 3.206444,
#    'longitude': 101.58082,
#    'bearing': 274.0,
#    'speed': 13.0},
#   'timestamp': '1886017556',
#   'vehicle': {'id': 'VAL4552', 'licensePlate': 'VAL4552'}}]

# %% [markdown]
# # static API

# %%
import requests
import zipfile
import io
import pandas as pd

url = "https://api.data.gov.my/gtfs-static/prasarana?category=rapid-bus-kl"

# Download
response = requests.get(url)
zip_file = zipfile.ZipFile(io.BytesIO(response.content))

# Read all text/csv files into dataframes
dataframes = {}
for name in zip_file.namelist():
    if name.endswith(".csv"):
        with zip_file.open(name) as f:
            dataframes[name] = pd.read_csv(f)
    elif name.endswith(".txt"):
        with zip_file.open(name) as f:
            dataframes[name] = pd.read_csv(f, sep="\t")  # adjust sep as needed

# Access individual dataframes
for name, df in dataframes.items():
    print(f"--- {name} ---")
    print(df.head())
# Out:
# --2026-03-22 20:13:30--  https://api.data.gov.my/gtfs-static/prasarana?category=rapid-bus-kl
# Resolving api.data.gov.my (api.data.gov.my)... 162.159.140.98, 172.66.0.96
# Connecting to api.data.gov.my (api.data.gov.my)|162.159.140.98|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /gtfs-static/prasarana/?category=rapid-bus-kl [following]
# --2026-03-22 20:13:31--  https://api.data.gov.my/gtfs-static/prasarana/?category=rapid-bus-kl
# Reusing existing connection to api.data.gov.my:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://openapi-malaysia-transport.s3.ap-southeast-1.amazonaws.com/prasarana/gtfs_rapid_bus_kl.zip [following]
# --2026-03-22 20:13:31--  https://openapi-malaysia-transport.s3.ap-southeast-1.amazonaws.com/prasarana/gtfs_rapid_bus_kl.zip
# Resolving openapi-malaysia-transport.s3.ap-southeast-1.amazonaws.com (openapi-malaysia-transport.s3.ap-southeast-1.amazonaws.com)... 3.5.147.167, 3.5.149.141, 3.5.149.61, ...
# Connecting to openapi-malaysia-transport.s3.ap-southeast-1.amazonaws.com (openapi-malaysia-transport.s3.ap-southeast-1.amazonaws.com)|3.5.147.167|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1591602 (1.5M) [binary/octet-stream]
# Saving to: ‘test.zip’
#
# test.zip            100%[===================>]   1.52M  1.65MB/s    in 0.9s
#
# 2026-03-22 20:13:32 (1.65 MB/s) - ‘test.zip’ saved [1591602/1591602]

# %%
# !ls
# Out:
# data-understanding.ipynb        test.zip
# prasarana?category=rapid-bus-kl
